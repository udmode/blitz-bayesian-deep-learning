# %%
import pandas as pd
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from blitz.modules import BayesianLSTM
from blitz.utils import variational_estimator

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt
# %matplotlib inline

from collections import deque

# %%
file_path = "data/"
input_file = "oanda_db_USD_JPY_M1_20240503133142.csv"
# https://www.histdata.com/download-free-forex-historical-data/?/metatrader/1-minute-bar-quotes/USDJPY
# input_file = "DAT_MT_USDJPY_M1_2020-02.csv"
df = pd.read_csv(f"{file_path}{input_file}")
df.head()
# Out:
#       ID                 Date     Open     High      Low    Close  Volume  \
# 0  44309  2024-03-19 00:00:00  149.286  149.294  149.284  149.288     102
# 1  44310  2024-03-19 00:01:00  149.288  149.288  149.276  149.286     116
# 2  44311  2024-03-19 00:02:00  149.286  149.288  149.260  149.265      58
# 3  44312  2024-03-19 00:03:00  149.265  149.266  149.251  149.254      56
# 4  44313  2024-03-19 00:04:00  149.254  149.254  149.240  149.241      45
#
#    Complete           Created_at           Updated_at
# 0         1  2024-04-28 20:00:35  2024-04-28 20:00:35
# 1         1  2024-04-28 20:00:35  2024-04-28 20:00:35
# 2         1  2024-04-28 20:00:35  2024-04-28 20:00:35
# 3         1  2024-04-28 20:00:35  2024-04-28 20:00:35
# 4         1  2024-04-28 20:00:35  2024-04-28 20:00:35

# %%
def create_timestamps_ds(series, timestep_size):
    print(f"series: {series}")
    print(f"timestep_size: {timestep_size}")
    """
    時系列データをモデルが処理できる形式に変換する
    """
    time_stamps = []
    labels = []

    # collectionsモジュールのdeque（デック）というデータ構造を使用する
    # dequeは、両端で要素の追加や削除が高速に行えるリスト型のデータ構造です
    aux_deque = deque(maxlen=timestep_size)
    print(f"aux_deque: {aux_deque}")
    # starting the timestep deque
    for i in range(timestep_size):
        aux_deque.append(0)
        print(f"range(timestep_size): {i}")
    #feed the timestamps list
    for i in range(len(series) - 1):
        aux_deque.append(series[i])
        time_stamps.append(list(aux_deque))
        print(f"range(len(series) - 1): {i}")
    #feed the labels lsit
    for i in range(len(series) - 1):
        labels.append(series[i + 1])
        print(f"range(len(series) - 1): {i}")

    assert len(time_stamps) == len(labels), "Something went wrong"

    # torch-tensoring it 浮動小数点数のテンソルに変換
    # テンソルは、多次元配列のようなもので、PyTorchではニューラルネットワークの入力データやパラメータ、出力データを表現するために使用される
    features = torch.tensor(time_stamps[timestep_size:]).float()
    labels = torch.tensor(labels[timestep_size:]).float()

    return features, labels

# %%
@variational_estimator
class NN(nn.Module):
    """
    ベイジアンLSTMを使用したニューラルネットワーク
    時系列データのパターンを学習し、未来の株価を予測するために使用される
    """

    def __init__(self):
        """
        ニューラルネットワークのレイヤーを定義する
        BayesianLSTMは、LSTM（Long Short-Term Memory）は、時系列データのパターンを学習するために使用される
        nn.Linearは、全結合レイヤー（線形レイヤー）であり、ニューラルネットワークの各レイヤーが前のレイヤーと全結合していることを意味する
        """
        super(NN, self).__init__()
        self.lstm_1 = BayesianLSTM(1, 10, prior_sigma_1=1, prior_pi=1, posterior_rho_init=-3.0)
        self.linear = nn.Linear(10, 1)

    def forward(self, x):
        """
        ニューラルネットワークの順伝播を定義する
        つまり、入力データがどのようにネットワークを通過し、出力を生成するかを定義
        まずBayesianLSTMレイヤーを通過し、その出力が全結合レイヤーに渡され、最終的な出力が生成される
        """
        x_, _ = self.lstm_1(x)

        #gathering only the latent end-of-sequence for the linear layer
        x_ = x_[:, -1, :]
        x_ = self.linear(x_)
        return x_

# %% [raw]
# `self.lstm_1 = BayesianLSTM(1, 10, prior_sigma_1=1, prior_pi=1, posterior_rho_init=-3.0)` は、ニューラルネットワークの一部であるLSTM（Long Short-Term Memory）レイヤーを定義しています。ここで使用されているのは、通常のLSTMではなく、ベイジアンLSTMと呼ばれる特殊な種類のLSTMです。
#
# - `BayesianLSTM(1, 10, prior_sigma_1=1, prior_pi=1, posterior_rho_init=-3.0)`：これは、BayesianLSTMレイヤーを作成するためのコンストラクタ呼び出しです。引数は次のように解釈されます：
#   - 最初の引数`1`は、入力の次元数を示します。この場合、各タイムステップでの入力は1次元です。
#   - 次の引数`10`は、LSTMレイヤーの隠れユニットの数を示します。これは、LSTMレイヤーの「容量」または「複雑さ」を制御します。
#   - `prior_sigma_1`、`prior_pi`、`posterior_rho_init`は、ベイジアンLSTMの動作を制御するためのパラメータです。これらは、ネットワークの重みの事前分布と事後分布を制御します。
#
# - `self.lstm_1 =`：これは、作成したBayesianLSTMレイヤーをニューラルネットワークの属性として保存しています。これにより、後でこのレイヤーを使用してデータを処理したり、レイヤーのパラメータを学習したりすることができます。
#
# このコード行全体は、ニューラルネットワークの一部としてベイジアンLSTMレイヤーを作成し、それをニューラルネットワークの属性として保存しています。このレイヤーは、後でニューラルネットワークの順伝播（データの処理）と逆伝播（パラメータの学習）の両方で使用されます。

# %%
close_prices = df["Close"]
# 特徴量のスケーリングを行うためのツールで、特に機械学習モデルを訓練する前にデータを前処理する際に使用される
scaler = StandardScaler()

# 2次元配列に変換
close_prices_arr = np.array(close_prices).reshape(-1, 1)
# スケーリング
close_prices = scaler.fit_transform(close_prices_arr)

# %%
# 時系列データを処理する際の「ウィンドウサイズ」を設定しています。
# ウィンドウサイズとは、一度にモデルが見る過去のデータポイントの数を指します。
# この場合、モデルは過去21ポイントのデータを見て、次のデータポイントを予測します。 
# この値は、時系列データをモデルが処理できる形式に変換する際に使用されます。
# create_timestamps_ds 関数内で、各ウィンドウ（または時間ステップ）に対応するデータポイントのセットを作成するために使用されます  
# ウィンドウサイズはハイパーパラメータであり、モデルの性能に影響を与えます。
window_size = 21
# 時系列データをモデルが処理できる形式に変換する。
# データを一定の時間窓で区切ったもの（Xs）と、それぞれの時間窓の次の値（ys）を生  
# Xsは各時間窓のデータを格納したリスト（または配列）で、ysはそれぞれの時間窓の次の値を格納したリスト
# これらは、時系列予測タスクにおける特徴量とラベルに相当します。
Xs, ys = create_timestamps_ds(close_prices, window_size)
# Out:
# series: [[-1.89692235]
#  [-1.89791017]
#  [-1.90828227]
#  ...
#  [ 0.45803945]
#  [ 0.46001509]
#  [ 0.46495419]]
# timestep_size: 21
# aux_deque: deque([], maxlen=21)
# range(timestep_size): 0
# range(timestep_size): 1
# range(timestep_size): 2
# range(timestep_size): 3
# range(timestep_size): 4
# range(timestep_size): 5
# range(timestep_size): 6
# range(timestep_size): 7
# range(timestep_size): 8
# range(timestep_size): 9
# range(timestep_size): 10
# range(timestep_size): 11
# range(timestep_size): 12
# range(timestep_size): 13
# range(timestep_size): 14
# range(timestep_size): 15
# range(timestep_size): 16
# range(timestep_size): 17
# range(timestep_size): 18
# range(timestep_size): 19
# range(timestep_size): 20
# range(len(series) - 1): 0
# range(len(series) - 1): 1
# range(len(series) - 1): 2
# range(len(series) - 1): 3
# range(len(series) - 1): 4
# range(len(series) - 1): 5
# range(len(series) - 1): 6
# range(len(series) - 1): 7
# range(len(series) - 1): 8
# range(len(series) - 1): 9
# range(len(series) - 1): 10
# range(len(series) - 1): 11
# range(len(series) - 1): 12
# range(len(series) - 1): 13
# range(len(series) - 1): 14
# range(len(series) - 1): 15
# range(len(series) - 1): 16
# range(len(series) - 1): 17
# range(len(series) - 1): 18
# range(len(series) - 1): 19
# range(len(series) - 1): 20
# range(len(series) - 1): 21
# range(len(series) - 1): 22
# range(len(series) - 1): 23
# range(len(series) - 1): 24
# range(len(series) - 1): 25
# range(len(series) - 1): 26
# range(len(series) - 1): 27
# range(len(series) - 1): 28
# range(len(series) - 1): 29
# range(len(series) - 1): 30
# range(len(series) - 1): 31
# range(len(series) - 1): 32
# range(len(series) - 1): 33
# range(len(series) - 1): 34
# range(len(series) - 1): 35
# range(len(series) - 1): 36
# range(len(series) - 1): 37
# range(len(series) - 1): 38
# range(len(series) - 1): 39
# range(len(series) - 1): 40
# range(len(series) - 1): 41
# range(len(series) - 1): 42
# range(len(series) - 1): 43
# range(len(series) - 1): 44
# range(len(series) - 1): 45
# range(len(series) - 1): 46
# range(len(series) - 1): 47
# range(len(series) - 1): 48
# range(len(series) - 1): 49
# range(len(series) - 1): 50
# range(len(series) - 1): 51
# range(len(series) - 1): 52
# range(len(series) - 1): 53
# range(len(series) - 1): 54
# range(len(series) - 1): 55
# range(len(series) - 1): 56
# range(len(series) - 1): 57
# range(len(series) - 1): 58
# range(len(series) - 1): 59
# range(len(series) - 1): 60
# range(len(series) - 1): 61
# range(len(series) - 1): 62
# range(len(series) - 1): 63
# range(len(series) - 1): 64
# range(len(series) - 1): 65
# range(len(series) - 1): 66
# range(len(series) - 1): 67
# range(len(series) - 1): 68
# range(len(series) - 1): 69
# range(len(series) - 1): 70
# range(len(series) - 1): 71
# range(len(series) - 1): 72
# range(len(series) - 1): 73
# range(len(series) - 1): 74
# range(len(series) - 1): 75
# range(len(series) - 1): 76
# range(len(series) - 1): 77
# range(len(series) - 1): 78
# range(len(series) - 1): 79
# range(len(series) - 1): 80
# range(len(series) - 1): 81
# range(len(series) - 1): 82
# range(len(series) - 1): 83
# range(len(series) - 1): 84
# range(len(series) - 1): 85
# range(len(series) - 1): 86
# range(len(series) - 1): 87
# range(len(series) - 1): 88
# range(len(series) - 1): 89
# range(len(series) - 1): 90
# range(len(series) - 1): 91
# range(len(series) - 1): 92
# range(len(series) - 1): 93
# range(len(series) - 1): 94
# range(len(series) - 1): 95
# range(len(series) - 1): 96
# range(len(series) - 1): 97
# range(len(series) - 1): 98
# range(len(series) - 1): 99
# range(len(series) - 1): 100
# range(len(series) - 1): 101
# range(len(series) - 1): 102
# range(len(series) - 1): 103
# range(len(series) - 1): 104
# range(len(series) - 1): 105
# range(len(series) - 1): 106
# range(len(series) - 1): 107
# range(len(series) - 1): 108
# range(len(series) - 1): 109
# range(len(series) - 1): 110
# range(len(series) - 1): 111
# range(len(series) - 1): 112
# range(len(series) - 1): 113
# range(len(series) - 1): 114
# range(len(series) - 1): 115
# range(len(series) - 1): 116
# range(len(series) - 1): 117
# range(len(series) - 1): 118
# range(len(series) - 1): 119
# range(len(series) - 1): 120
# range(len(series) - 1): 121
# range(len(series) - 1): 122
# range(len(series) - 1): 123
# range(len(series) - 1): 124
# range(len(series) - 1): 125
# range(len(series) - 1): 126
# range(len(series) - 1): 127
# range(len(series) - 1): 128
# range(len(series) - 1): 129
# range(len(series) - 1): 130
# range(len(series) - 1): 131
# range(len(series) - 1): 132
# range(len(series) - 1): 133
# range(len(series) - 1): 134
# range(len(series) - 1): 135
# range(len(series) - 1): 136
# range(len(series) - 1): 137
# range(len(series) - 1): 138
# range(len(series) - 1): 139
# range(len(series) - 1): 140
# range(len(series) - 1): 141
# range(len(series) - 1): 142
# range(len(series) - 1): 143
# range(len(series) - 1): 144
# range(len(series) - 1): 145
# range(len(series) - 1): 146
# range(len(series) - 1): 147
# range(len(series) - 1): 148
# range(len(series) - 1): 149
# range(len(series) - 1): 150
# range(len(series) - 1): 151
# range(len(series) - 1): 152
# range(len(series) - 1): 153
# range(len(series) - 1): 154
# range(len(series) - 1): 155
# range(len(series) - 1): 156
# range(len(series) - 1): 157
# range(len(series) - 1): 158
# range(len(series) - 1): 159
# range(len(series) - 1): 160
# range(len(series) - 1): 161
# range(len(series) - 1): 162
# range(len(series) - 1): 163
# range(len(series) - 1): 164
# range(len(series) - 1): 165
# range(len(series) - 1): 166
# range(len(series) - 1): 167
# range(len(series) - 1): 168
# range(len(series) - 1): 169
# range(len(series) - 1): 170
# range(len(series) - 1): 171
# range(len(series) - 1): 172
# range(len(series) - 1): 173
# range(len(series) - 1): 174
# range(len(series) - 1): 175
# range(len(series) - 1): 176
# range(len(series) - 1): 177
# range(len(series) - 1): 178
# range(len(series) - 1): 179
# range(len(series) - 1): 180
# range(len(series) - 1): 181
# range(len(series) - 1): 182
# range(len(series) - 1): 183
# range(len(series) - 1): 184
# range(len(series) - 1): 185
# range(len(series) - 1): 186
# range(len(series) - 1): 187
# range(len(series) - 1): 188
# range(len(series) - 1): 189
# range(len(series) - 1): 190
# range(len(series) - 1): 191
# range(len(series) - 1): 192
# range(len(series) - 1): 193
# range(len(series) - 1): 194
# range(len(series) - 1): 195
# range(len(series) - 1): 196
# range(len(series) - 1): 197
# range(len(series) - 1): 198
# range(len(series) - 1): 199
# range(len(series) - 1): 200
# range(len(series) - 1): 201
# range(len(series) - 1): 202
# range(len(series) - 1): 203
# range(len(series) - 1): 204
# range(len(series) - 1): 205
# range(len(series) - 1): 206
# range(len(series) - 1): 207
# range(len(series) - 1): 208
# range(len(series) - 1): 209
# range(len(series) - 1): 210
# range(len(series) - 1): 211
# range(len(series) - 1): 212
# range(len(series) - 1): 213
# range(len(series) - 1): 214
# range(len(series) - 1): 215
# range(len(series) - 1): 216
# range(len(series) - 1): 217
# range(len(series) - 1): 218
# range(len(series) - 1): 219
# range(len(series) - 1): 220
# range(len(series) - 1): 221
# range(len(series) - 1): 222
# range(len(series) - 1): 223
# range(len(series) - 1): 224
# range(len(series) - 1): 225
# range(len(series) - 1): 226
# range(len(series) - 1): 227
# range(len(series) - 1): 228
# range(len(series) - 1): 229
# range(len(series) - 1): 230
# range(len(series) - 1): 231
# range(len(series) - 1): 232
# range(len(series) - 1): 233
# range(len(series) - 1): 234
# range(len(series) - 1): 235
# range(len(series) - 1): 236
# range(len(series) - 1): 237
# range(len(series) - 1): 238
# range(len(series) - 1): 239
# range(len(series) - 1): 240
# range(len(series) - 1): 241
# range(len(series) - 1): 242
# range(len(series) - 1): 243
# range(len(series) - 1): 244
# range(len(series) - 1): 245
# range(len(series) - 1): 246
# range(len(series) - 1): 247
# range(len(series) - 1): 248
# range(len(series) - 1): 249
# range(len(series) - 1): 250
# range(len(series) - 1): 251
# range(len(series) - 1): 252
# range(len(series) - 1): 253
# range(len(series) - 1): 254
# range(len(series) - 1): 255
# range(len(series) - 1): 256
# range(len(series) - 1): 257
# range(len(series) - 1): 258
# range(len(series) - 1): 259
# range(len(series) - 1): 260
# range(len(series) - 1): 261
# range(len(series) - 1): 262
# range(len(series) - 1): 263
# range(len(series) - 1): 264
# range(len(series) - 1): 265
# range(len(series) - 1): 266
# range(len(series) - 1): 267
# range(len(series) - 1): 268
# range(len(series) - 1): 269
# range(len(series) - 1): 270
# range(len(series) - 1): 271
# range(len(series) - 1): 272
# range(len(series) - 1): 273
# range(len(series) - 1): 274
# range(len(series) - 1): 275
# range(len(series) - 1): 276
# range(len(series) - 1): 277
# range(len(series) - 1): 278
# range(len(series) - 1): 279
# range(len(series) - 1): 280
# range(len(series) - 1): 281
# range(len(series) - 1): 282
# range(len(series) - 1): 283
# range(len(series) - 1): 284
# range(len(series) - 1): 285
# range(len(series) - 1): 286
# range(len(series) - 1): 287
# range(len(series) - 1): 288
# range(len(series) - 1): 289
# range(len(series) - 1): 290
# range(len(series) - 1): 291
# range(len(series) - 1): 292
# range(len(series) - 1): 293
# range(len(series) - 1): 294
# range(len(series) - 1): 295
# range(len(series) - 1): 296
# range(len(series) - 1): 297
# range(len(series) - 1): 298
# range(len(series) - 1): 299
# range(len(series) - 1): 300
# range(len(series) - 1): 301
# range(len(series) - 1): 302
# range(len(series) - 1): 303
# range(len(series) - 1): 304
# range(len(series) - 1): 305
# range(len(series) - 1): 306
# range(len(series) - 1): 307
# range(len(series) - 1): 308
# range(len(series) - 1): 309
# range(len(series) - 1): 310
# range(len(series) - 1): 311
# range(len(series) - 1): 312
# range(len(series) - 1): 313
# range(len(series) - 1): 314
# range(len(series) - 1): 315
# range(len(series) - 1): 316
# range(len(series) - 1): 317
# range(len(series) - 1): 318
# range(len(series) - 1): 319
# range(len(series) - 1): 320
# range(len(series) - 1): 321
# range(len(series) - 1): 322
# range(len(series) - 1): 323
# range(len(series) - 1): 324
# range(len(series) - 1): 325
# range(len(series) - 1): 326
# range(len(series) - 1): 327
# range(len(series) - 1): 328
# range(len(series) - 1): 329
# range(len(series) - 1): 330
# range(len(series) - 1): 331
# range(len(series) - 1): 332
# range(len(series) - 1): 333
# range(len(series) - 1): 334
# range(len(series) - 1): 335
# range(len(series) - 1): 336
# range(len(series) - 1): 337
# range(len(series) - 1): 338
# range(len(series) - 1): 339
# range(len(series) - 1): 340
# range(len(series) - 1): 341
# range(len(series) - 1): 342
# range(len(series) - 1): 343
# range(len(series) - 1): 344
# range(len(series) - 1): 345
# range(len(series) - 1): 346
# range(len(series) - 1): 347
# range(len(series) - 1): 348
# range(len(series) - 1): 349
# range(len(series) - 1): 350
# range(len(series) - 1): 351
# range(len(series) - 1): 352
# range(len(series) - 1): 353
# range(len(series) - 1): 354
# range(len(series) - 1): 355
# range(len(series) - 1): 356
# range(len(series) - 1): 357
# range(len(series) - 1): 358
# range(len(series) - 1): 359
# range(len(series) - 1): 360
# range(len(series) - 1): 361
# range(len(series) - 1): 362
# range(len(series) - 1): 363
# range(len(series) - 1): 364
# range(len(series) - 1): 365
# range(len(series) - 1): 366
# range(len(series) - 1): 367
# range(len(series) - 1): 368
# range(len(series) - 1): 369
# range(len(series) - 1): 370
# range(len(series) - 1): 371
# range(len(series) - 1): 372
# range(len(series) - 1): 373
# range(len(series) - 1): 374
# range(len(series) - 1): 375
# range(len(series) - 1): 376
# range(len(series) - 1): 377
# range(len(series) - 1): 378
# range(len(series) - 1): 379
# range(len(series) - 1): 380
# range(len(series) - 1): 381
# range(len(series) - 1): 382
# range(len(series) - 1): 383
# range(len(series) - 1): 384
# range(len(series) - 1): 385
# range(len(series) - 1): 386
# range(len(series) - 1): 387
# range(len(series) - 1): 388
# range(len(series) - 1): 389
# range(len(series) - 1): 390
# range(len(series) - 1): 391
# range(len(series) - 1): 392
# range(len(series) - 1): 393
# range(len(series) - 1): 394
# range(len(series) - 1): 395
# range(len(series) - 1): 396
# range(len(series) - 1): 397
# range(len(series) - 1): 398
# range(len(series) - 1): 399
# range(len(series) - 1): 400
# range(len(series) - 1): 401
# range(len(series) - 1): 402
# range(len(series) - 1): 403
# range(len(series) - 1): 404
# range(len(series) - 1): 405
# range(len(series) - 1): 406
# range(len(series) - 1): 407
# range(len(series) - 1): 408
# range(len(series) - 1): 409
# range(len(series) - 1): 410
# range(len(series) - 1): 411
# range(len(series) - 1): 412
# range(len(series) - 1): 413
# range(len(series) - 1): 414
# range(len(series) - 1): 415
# range(len(series) - 1): 416
# range(len(series) - 1): 417
# range(len(series) - 1): 418
# range(len(series) - 1): 419
# range(len(series) - 1): 420
# range(len(series) - 1): 421
# range(len(series) - 1): 422
# range(len(series) - 1): 423
# range(len(series) - 1): 424
# range(len(series) - 1): 425
# range(len(series) - 1): 426
# range(len(series) - 1): 427
# range(len(series) - 1): 428
# range(len(series) - 1): 429
# range(len(series) - 1): 430
# range(len(series) - 1): 431
# range(len(series) - 1): 432
# range(len(series) - 1): 433
# range(len(series) - 1): 434
# range(len(series) - 1): 435
# range(len(series) - 1): 436
# range(len(series) - 1): 437
# range(len(series) - 1): 438
# range(len(series) - 1): 439
# range(len(series) - 1): 440
# range(len(series) - 1): 441
# range(len(series) - 1): 442
# range(len(series) - 1): 443
# range(len(series) - 1): 444
# range(len(series) - 1): 445
# range(len(series) - 1): 446
# range(len(series) - 1): 447
# range(len(series) - 1): 448
# range(len(series) - 1): 449
# range(len(series) - 1): 450
# range(len(series) - 1): 451
# range(len(series) - 1): 452
# range(len(series) - 1): 453
# range(len(series) - 1): 454
# range(len(series) - 1): 455
# range(len(series) - 1): 456
# range(len(series) - 1): 457
# range(len(series) - 1): 458
# range(len(series) - 1): 459
# range(len(series) - 1): 460
# range(len(series) - 1): 461
# range(len(series) - 1): 462
# range(len(series) - 1): 463
# range(len(series) - 1): 464
# range(len(series) - 1): 465
# range(len(series) - 1): 466
# range(len(series) - 1): 467
# range(len(series) - 1): 468
# range(len(series) - 1): 469
# range(len(series) - 1): 470
# range(len(series) - 1): 471
# range(len(series) - 1): 472
# range(len(series) - 1): 473
# range(len(series) - 1): 474
# range(len(series) - 1): 475
# range(len(series) - 1): 476
# range(len(series) - 1): 477
# range(len(series) - 1): 478
# range(len(series) - 1): 479
# range(len(series) - 1): 480
# range(len(series) - 1): 481
# range(len(series) - 1): 482
# range(len(series) - 1): 483
# range(len(series) - 1): 484
# range(len(series) - 1): 485
# range(len(series) - 1): 486
# range(len(series) - 1): 487
# range(len(series) - 1): 488
# range(len(series) - 1): 489
# range(len(series) - 1): 490
# range(len(series) - 1): 491
# range(len(series) - 1): 492
# range(len(series) - 1): 493
# range(len(series) - 1): 494
# range(len(series) - 1): 495
# range(len(series) - 1): 496
# range(len(series) - 1): 497
# range(len(series) - 1): 498
# range(len(series) - 1): 499
# range(len(series) - 1): 500
# range(len(series) - 1): 501
# range(len(series) - 1): 502
# range(len(series) - 1): 503
# range(len(series) - 1): 504
# range(len(series) - 1): 505
# range(len(series) - 1): 506
# range(len(series) - 1): 507
# range(len(series) - 1): 508
# range(len(series) - 1): 509
# range(len(series) - 1): 510
# range(len(series) - 1): 511
# range(len(series) - 1): 512
# range(len(series) - 1): 513
# range(len(series) - 1): 514
# range(len(series) - 1): 515
# range(len(series) - 1): 516
# range(len(series) - 1): 517
# range(len(series) - 1): 518
# range(len(series) - 1): 519
# range(len(series) - 1): 520
# range(len(series) - 1): 521
# range(len(series) - 1): 522
# range(len(series) - 1): 523
# range(len(series) - 1): 524
# range(len(series) - 1): 525
# range(len(series) - 1): 526
# range(len(series) - 1): 527
# range(len(series) - 1): 528
# range(len(series) - 1): 529
# range(len(series) - 1): 530
# range(len(series) - 1): 531
# range(len(series) - 1): 532
# range(len(series) - 1): 533
# range(len(series) - 1): 534
# range(len(series) - 1): 535
# range(len(series) - 1): 536
# range(len(series) - 1): 537
# range(len(series) - 1): 538
# range(len(series) - 1): 539
# range(len(series) - 1): 540
# range(len(series) - 1): 541
# range(len(series) - 1): 542
# range(len(series) - 1): 543
# range(len(series) - 1): 544
# range(len(series) - 1): 545
# range(len(series) - 1): 546
# range(len(series) - 1): 547
# range(len(series) - 1): 548
# range(len(series) - 1): 549
# range(len(series) - 1): 550
# range(len(series) - 1): 551
# range(len(series) - 1): 552
# range(len(series) - 1): 553
# range(len(series) - 1): 554
# range(len(series) - 1): 555
# range(len(series) - 1): 556
# range(len(series) - 1): 557
# range(len(series) - 1): 558
# range(len(series) - 1): 559
# range(len(series) - 1): 560
# range(len(series) - 1): 561
# range(len(series) - 1): 562
# range(len(series) - 1): 563
# range(len(series) - 1): 564
# range(len(series) - 1): 565
# range(len(series) - 1): 566
# range(len(series) - 1): 567
# range(len(series) - 1): 568
# range(len(series) - 1): 569
# range(len(series) - 1): 570
# range(len(series) - 1): 571
# range(len(series) - 1): 572
# range(len(series) - 1): 573
# range(len(series) - 1): 574
# range(len(series) - 1): 575
# range(len(series) - 1): 576
# range(len(series) - 1): 577
# range(len(series) - 1): 578
# range(len(series) - 1): 579
# range(len(series) - 1): 580
# range(len(series) - 1): 581
# range(len(series) - 1): 582
# range(len(series) - 1): 583
# range(len(series) - 1): 584
# range(len(series) - 1): 585
# range(len(series) - 1): 586
# range(len(series) - 1): 587
# range(len(series) - 1): 588
# range(len(series) - 1): 589
# range(len(series) - 1): 590
# range(len(series) - 1): 591
# range(len(series) - 1): 592
# range(len(series) - 1): 593
# range(len(series) - 1): 594
# range(len(series) - 1): 595
# range(len(series) - 1): 596
# range(len(series) - 1): 597
# range(len(series) - 1): 598
# range(len(series) - 1): 599
# range(len(series) - 1): 600
# range(len(series) - 1): 601
# range(len(series) - 1): 602
# range(len(series) - 1): 603
# range(len(series) - 1): 604
# range(len(series) - 1): 605
# range(len(series) - 1): 606
# range(len(series) - 1): 607
# range(len(series) - 1): 608
# range(len(series) - 1): 609
# range(len(series) - 1): 610
# range(len(series) - 1): 611
# range(len(series) - 1): 612
# range(len(series) - 1): 613
# range(len(series) - 1): 614
# range(len(series) - 1): 615
# range(len(series) - 1): 616
# range(len(series) - 1): 617
# range(len(series) - 1): 618
# range(len(series) - 1): 619
# range(len(series) - 1): 620
# range(len(series) - 1): 621
# range(len(series) - 1): 622
# range(len(series) - 1): 623
# range(len(series) - 1): 624
# range(len(series) - 1): 625
# range(len(series) - 1): 626
# range(len(series) - 1): 627
# range(len(series) - 1): 628
# range(len(series) - 1): 629
# range(len(series) - 1): 630
# range(len(series) - 1): 631
# range(len(series) - 1): 632
# range(len(series) - 1): 633
# range(len(series) - 1): 634
# range(len(series) - 1): 635
# range(len(series) - 1): 636
# range(len(series) - 1): 637
# range(len(series) - 1): 638
# range(len(series) - 1): 639
# range(len(series) - 1): 640
# range(len(series) - 1): 641
# range(len(series) - 1): 642
# range(len(series) - 1): 643
# range(len(series) - 1): 644
# range(len(series) - 1): 645
# range(len(series) - 1): 646
# range(len(series) - 1): 647
# range(len(series) - 1): 648
# range(len(series) - 1): 649
# range(len(series) - 1): 650
# range(len(series) - 1): 651
# range(len(series) - 1): 652
# range(len(series) - 1): 653
# range(len(series) - 1): 654
# range(len(series) - 1): 655
# range(len(series) - 1): 656
# range(len(series) - 1): 657
# range(len(series) - 1): 658
# range(len(series) - 1): 659
# range(len(series) - 1): 660
# range(len(series) - 1): 661
# range(len(series) - 1): 662
# range(len(series) - 1): 663
# range(len(series) - 1): 664
# range(len(series) - 1): 665
# range(len(series) - 1): 666
# range(len(series) - 1): 667
# range(len(series) - 1): 668
# range(len(series) - 1): 669
# range(len(series) - 1): 670
# range(len(series) - 1): 671
# range(len(series) - 1): 672
# range(len(series) - 1): 673
# range(len(series) - 1): 674
# range(len(series) - 1): 675
# range(len(series) - 1): 676
# range(len(series) - 1): 677
# range(len(series) - 1): 678
# range(len(series) - 1): 679
# range(len(series) - 1): 680
# range(len(series) - 1): 681
# range(len(series) - 1): 682
# range(len(series) - 1): 683
# range(len(series) - 1): 684
# range(len(series) - 1): 685
# range(len(series) - 1): 686
# range(len(series) - 1): 687
# range(len(series) - 1): 688
# range(len(series) - 1): 689
# range(len(series) - 1): 690
# range(len(series) - 1): 691
# range(len(series) - 1): 692
# range(len(series) - 1): 693
# range(len(series) - 1): 694
# range(len(series) - 1): 695
# range(len(series) - 1): 696
# range(len(series) - 1): 697
# range(len(series) - 1): 698
# range(len(series) - 1): 699
# range(len(series) - 1): 700
# range(len(series) - 1): 701
# range(len(series) - 1): 702
# range(len(series) - 1): 703
# range(len(series) - 1): 704
# range(len(series) - 1): 705
# range(len(series) - 1): 706
# range(len(series) - 1): 707
# range(len(series) - 1): 708
# range(len(series) - 1): 709
# range(len(series) - 1): 710
# range(len(series) - 1): 711
# range(len(series) - 1): 712
# range(len(series) - 1): 713
# range(len(series) - 1): 714
# range(len(series) - 1): 715
# range(len(series) - 1): 716
# range(len(series) - 1): 717
# range(len(series) - 1): 718
# range(len(series) - 1): 719
# range(len(series) - 1): 720
# range(len(series) - 1): 721
# range(len(series) - 1): 722
# range(len(series) - 1): 723
# range(len(series) - 1): 724
# range(len(series) - 1): 725
# range(len(series) - 1): 726
# range(len(series) - 1): 727
# range(len(series) - 1): 728
# range(len(series) - 1): 729
# range(len(series) - 1): 730
# range(len(series) - 1): 731
# range(len(series) - 1): 732
# range(len(series) - 1): 733
# range(len(series) - 1): 734
# range(len(series) - 1): 735
# range(len(series) - 1): 736
# range(len(series) - 1): 737
# range(len(series) - 1): 738
# range(len(series) - 1): 739
# range(len(series) - 1): 740
# range(len(series) - 1): 741
# range(len(series) - 1): 742
# range(len(series) - 1): 743
# range(len(series) - 1): 744
# range(len(series) - 1): 745
# range(len(series) - 1): 746
# range(len(series) - 1): 747
# range(len(series) - 1): 748
# range(len(series) - 1): 749
# range(len(series) - 1): 750
# range(len(series) - 1): 751
# range(len(series) - 1): 752
# range(len(series) - 1): 753
# range(len(series) - 1): 754
# range(len(series) - 1): 755
# range(len(series) - 1): 756
# range(len(series) - 1): 757
# range(len(series) - 1): 758
# range(len(series) - 1): 759
# range(len(series) - 1): 760
# range(len(series) - 1): 761
# range(len(series) - 1): 762
# range(len(series) - 1): 763
# range(len(series) - 1): 764
# range(len(series) - 1): 765
# range(len(series) - 1): 766
# range(len(series) - 1): 767
# range(len(series) - 1): 768
# range(len(series) - 1): 769
# range(len(series) - 1): 770
# range(len(series) - 1): 771
# range(len(series) - 1): 772
# range(len(series) - 1): 773
# range(len(series) - 1): 774
# range(len(series) - 1): 775
# range(len(series) - 1): 776
# range(len(series) - 1): 777
# range(len(series) - 1): 778
# range(len(series) - 1): 779
# range(len(series) - 1): 780
# range(len(series) - 1): 781
# range(len(series) - 1): 782
# range(len(series) - 1): 783
# range(len(series) - 1): 784
# range(len(series) - 1): 785
# range(len(series) - 1): 786
# range(len(series) - 1): 787
# range(len(series) - 1): 788
# range(len(series) - 1): 789
# range(len(series) - 1): 790
# range(len(series) - 1): 791
# range(len(series) - 1): 792
# range(len(series) - 1): 793
# range(len(series) - 1): 794
# range(len(series) - 1): 795
# range(len(series) - 1): 796
# range(len(series) - 1): 797
# range(len(series) - 1): 798
# range(len(series) - 1): 799
# range(len(series) - 1): 800
# range(len(series) - 1): 801
# range(len(series) - 1): 802
# range(len(series) - 1): 803
# range(len(series) - 1): 804
# range(len(series) - 1): 805
# range(len(series) - 1): 806
# range(len(series) - 1): 807
# range(len(series) - 1): 808
# range(len(series) - 1): 809
# range(len(series) - 1): 810
# range(len(series) - 1): 811
# range(len(series) - 1): 812
# range(len(series) - 1): 813
# range(len(series) - 1): 814
# range(len(series) - 1): 815
# range(len(series) - 1): 816
# range(len(series) - 1): 817
# range(len(series) - 1): 818
# range(len(series) - 1): 819
# range(len(series) - 1): 820
# range(len(series) - 1): 821
# range(len(series) - 1): 822
# range(len(series) - 1): 823
# range(len(series) - 1): 824
# range(len(series) - 1): 825
# range(len(series) - 1): 826
# range(len(series) - 1): 827
# range(len(series) - 1): 828
# range(len(series) - 1): 829
# range(len(series) - 1): 830
# range(len(series) - 1): 831
# range(len(series) - 1): 832
# range(len(series) - 1): 833
# range(len(series) - 1): 834
# range(len(series) - 1): 835
# range(len(series) - 1): 836
# range(len(series) - 1): 837
# range(len(series) - 1): 838
# range(len(series) - 1): 839
# range(len(series) - 1): 840
# range(len(series) - 1): 841
# range(len(series) - 1): 842
# range(len(series) - 1): 843
# range(len(series) - 1): 844
# range(len(series) - 1): 845
# range(len(series) - 1): 846
# range(len(series) - 1): 847
# range(len(series) - 1): 848
# range(len(series) - 1): 849
# range(len(series) - 1): 850
# range(len(series) - 1): 851
# range(len(series) - 1): 852
# range(len(series) - 1): 853
# range(len(series) - 1): 854
# range(len(series) - 1): 855
# range(len(series) - 1): 856
# range(len(series) - 1): 857
# range(len(series) - 1): 858
# range(len(series) - 1): 859
# range(len(series) - 1): 860
# range(len(series) - 1): 861
# range(len(series) - 1): 862
# range(len(series) - 1): 863
# range(len(series) - 1): 864
# range(len(series) - 1): 865
# range(len(series) - 1): 866
# range(len(series) - 1): 867
# range(len(series) - 1): 868
# range(len(series) - 1): 869
# range(len(series) - 1): 870
# range(len(series) - 1): 871
# range(len(series) - 1): 872
# range(len(series) - 1): 873
# range(len(series) - 1): 874
# range(len(series) - 1): 875
# range(len(series) - 1): 876
# range(len(series) - 1): 877
# range(len(series) - 1): 878
# range(len(series) - 1): 879
# range(len(series) - 1): 880
# range(len(series) - 1): 881
# range(len(series) - 1): 882
# range(len(series) - 1): 883
# range(len(series) - 1): 884
# range(len(series) - 1): 885
# range(len(series) - 1): 886
# range(len(series) - 1): 887
# range(len(series) - 1): 888
# range(len(series) - 1): 889
# range(len(series) - 1): 890
# range(len(series) - 1): 891
# range(len(series) - 1): 892
# range(len(series) - 1): 893
# range(len(series) - 1): 894
# range(len(series) - 1): 895
# range(len(series) - 1): 896
# range(len(series) - 1): 897
# range(len(series) - 1): 898
# range(len(series) - 1): 899
# range(len(series) - 1): 900
# range(len(series) - 1): 901
# range(len(series) - 1): 902
# range(len(series) - 1): 903
# range(len(series) - 1): 904
# range(len(series) - 1): 905
# range(len(series) - 1): 906
# range(len(series) - 1): 907
# range(len(series) - 1): 908
# range(len(series) - 1): 909
# range(len(series) - 1): 910
# range(len(series) - 1): 911
# range(len(series) - 1): 912
# range(len(series) - 1): 913
# range(len(series) - 1): 914
# range(len(series) - 1): 915
# range(len(series) - 1): 916
# range(len(series) - 1): 917
# range(len(series) - 1): 918
# range(len(series) - 1): 919
# range(len(series) - 1): 920
# range(len(series) - 1): 921
# range(len(series) - 1): 922
# range(len(series) - 1): 923
# range(len(series) - 1): 924
# range(len(series) - 1): 925
# range(len(series) - 1): 926
# range(len(series) - 1): 927
# range(len(series) - 1): 928
# range(len(series) - 1): 929
# range(len(series) - 1): 930
# range(len(series) - 1): 931
# range(len(series) - 1): 932
# range(len(series) - 1): 933
# range(len(series) - 1): 934
# range(len(series) - 1): 935
# range(len(series) - 1): 936
# range(len(series) - 1): 937
# range(len(series) - 1): 938
# range(len(series) - 1): 939
# range(len(series) - 1): 940
# range(len(series) - 1): 941
# range(len(series) - 1): 942
# range(len(series) - 1): 943
# range(len(series) - 1): 944
# range(len(series) - 1): 945
# range(len(series) - 1): 946
# range(len(series) - 1): 947
# range(len(series) - 1): 948
# range(len(series) - 1): 949
# range(len(series) - 1): 950
# range(len(series) - 1): 951
# range(len(series) - 1): 952
# range(len(series) - 1): 953
# range(len(series) - 1): 954
# range(len(series) - 1): 955
# range(len(series) - 1): 956
# range(len(series) - 1): 957
# range(len(series) - 1): 958
# range(len(series) - 1): 959
# range(len(series) - 1): 960
# range(len(series) - 1): 961
# range(len(series) - 1): 962
# range(len(series) - 1): 963
# range(len(series) - 1): 964
# range(len(series) - 1): 965
# range(len(series) - 1): 966
# range(len(series) - 1): 967
# range(len(series) - 1): 968
# range(len(series) - 1): 969
# range(len(series) - 1): 970
# range(len(series) - 1): 971
# range(len(series) - 1): 972
# range(len(series) - 1): 973
# range(len(series) - 1): 974
# range(len(series) - 1): 975
# range(len(series) - 1): 976
# range(len(series) - 1): 977
# range(len(series) - 1): 978
# range(len(series) - 1): 979
# range(len(series) - 1): 980
# range(len(series) - 1): 981
# range(len(series) - 1): 982
# range(len(series) - 1): 983
# range(len(series) - 1): 984
# range(len(series) - 1): 985
# range(len(series) - 1): 986
# range(len(series) - 1): 987
# range(len(series) - 1): 988
# range(len(series) - 1): 989
# range(len(series) - 1): 990
# range(len(series) - 1): 991
# range(len(series) - 1): 992
# range(len(series) - 1): 993
# range(len(series) - 1): 994
# range(len(series) - 1): 995
# range(len(series) - 1): 996
# range(len(series) - 1): 997
# range(len(series) - 1): 998
# range(len(series) - 1): 999
# range(len(series) - 1): 1000
# range(len(series) - 1): 1001
# range(len(series) - 1): 1002
# range(len(series) - 1): 1003
# range(len(series) - 1): 1004
# range(len(series) - 1): 1005
# range(len(series) - 1): 1006
# range(len(series) - 1): 1007
# range(len(series) - 1): 1008
# range(len(series) - 1): 1009
# range(len(series) - 1): 1010
# range(len(series) - 1): 1011
# range(len(series) - 1): 1012
# range(len(series) - 1): 1013
# range(len(series) - 1): 1014
# range(len(series) - 1): 1015
# range(len(series) - 1): 1016
# range(len(series) - 1): 1017
# range(len(series) - 1): 1018
# range(len(series) - 1): 1019
# range(len(series) - 1): 1020
# range(len(series) - 1): 1021
# range(len(series) - 1): 1022
# range(len(series) - 1): 1023
# range(len(series) - 1): 1024
# range(len(series) - 1): 1025
# range(len(series) - 1): 1026
# range(len(series) - 1): 1027
# range(len(series) - 1): 1028
# range(len(series) - 1): 1029
# range(len(series) - 1): 1030
# range(len(series) - 1): 1031
# range(len(series) - 1): 1032
# range(len(series) - 1): 1033
# range(len(series) - 1): 1034
# range(len(series) - 1): 1035
# range(len(series) - 1): 1036
# range(len(series) - 1): 1037
# range(len(series) - 1): 1038
# range(len(series) - 1): 1039
# range(len(series) - 1): 1040
# range(len(series) - 1): 1041
# range(len(series) - 1): 1042
# range(len(series) - 1): 1043
# range(len(series) - 1): 1044
# range(len(series) - 1): 1045
# range(len(series) - 1): 1046
# range(len(series) - 1): 1047
# range(len(series) - 1): 1048
# range(len(series) - 1): 1049
# range(len(series) - 1): 1050
# range(len(series) - 1): 1051
# range(len(series) - 1): 1052
# range(len(series) - 1): 1053
# range(len(series) - 1): 1054
# range(len(series) - 1): 1055
# range(len(series) - 1): 1056
# range(len(series) - 1): 1057
# range(len(series) - 1): 1058
# range(len(series) - 1): 1059
# range(len(series) - 1): 1060
# range(len(series) - 1): 1061
# range(len(series) - 1): 1062
# range(len(series) - 1): 1063
# range(len(series) - 1): 1064
# range(len(series) - 1): 1065
# range(len(series) - 1): 1066
# range(len(series) - 1): 1067
# range(len(series) - 1): 1068
# range(len(series) - 1): 1069
# range(len(series) - 1): 1070
# range(len(series) - 1): 1071
# range(len(series) - 1): 1072
# range(len(series) - 1): 1073
# range(len(series) - 1): 1074
# range(len(series) - 1): 1075
# range(len(series) - 1): 1076
# range(len(series) - 1): 1077
# range(len(series) - 1): 1078
# range(len(series) - 1): 1079
# range(len(series) - 1): 1080
# range(len(series) - 1): 1081
# range(len(series) - 1): 1082
# range(len(series) - 1): 1083
# range(len(series) - 1): 1084
# range(len(series) - 1): 1085
# range(len(series) - 1): 1086
# range(len(series) - 1): 1087
# range(len(series) - 1): 1088
# range(len(series) - 1): 1089
# range(len(series) - 1): 1090
# range(len(series) - 1): 1091
# range(len(series) - 1): 1092
# range(len(series) - 1): 1093
# range(len(series) - 1): 1094
# range(len(series) - 1): 1095
# range(len(series) - 1): 1096
# range(len(series) - 1): 1097
# range(len(series) - 1): 1098
# range(len(series) - 1): 1099
# range(len(series) - 1): 1100
# range(len(series) - 1): 1101
# range(len(series) - 1): 1102
# range(len(series) - 1): 1103
# range(len(series) - 1): 1104
# range(len(series) - 1): 1105
# range(len(series) - 1): 1106
# range(len(series) - 1): 1107
# range(len(series) - 1): 1108
# range(len(series) - 1): 1109
# range(len(series) - 1): 1110
# range(len(series) - 1): 1111
# range(len(series) - 1): 1112
# range(len(series) - 1): 1113
# range(len(series) - 1): 1114
# range(len(series) - 1): 1115
# range(len(series) - 1): 1116
# range(len(series) - 1): 1117
# range(len(series) - 1): 1118
# range(len(series) - 1): 1119
# range(len(series) - 1): 1120
# range(len(series) - 1): 1121
# range(len(series) - 1): 1122
# range(len(series) - 1): 1123
# range(len(series) - 1): 1124
# range(len(series) - 1): 1125
# range(len(series) - 1): 1126
# range(len(series) - 1): 1127
# range(len(series) - 1): 1128
# range(len(series) - 1): 1129
# range(len(series) - 1): 1130
# range(len(series) - 1): 1131
# range(len(series) - 1): 1132
# range(len(series) - 1): 1133
# range(len(series) - 1): 1134
# range(len(series) - 1): 1135
# range(len(series) - 1): 1136
# range(len(series) - 1): 1137
# range(len(series) - 1): 1138
# range(len(series) - 1): 1139
# range(len(series) - 1): 1140
# range(len(series) - 1): 1141
# range(len(series) - 1): 1142
# range(len(series) - 1): 1143
# range(len(series) - 1): 1144
# range(len(series) - 1): 1145
# range(len(series) - 1): 1146
# range(len(series) - 1): 1147
# range(len(series) - 1): 1148
# range(len(series) - 1): 1149
# range(len(series) - 1): 1150
# range(len(series) - 1): 1151
# range(len(series) - 1): 1152
# range(len(series) - 1): 1153
# range(len(series) - 1): 1154
# range(len(series) - 1): 1155
# range(len(series) - 1): 1156
# range(len(series) - 1): 1157
# range(len(series) - 1): 1158
# range(len(series) - 1): 1159
# range(len(series) - 1): 1160
# range(len(series) - 1): 1161
# range(len(series) - 1): 1162
# range(len(series) - 1): 1163
# range(len(series) - 1): 1164
# range(len(series) - 1): 1165
# range(len(series) - 1): 1166
# range(len(series) - 1): 1167
# range(len(series) - 1): 1168
# range(len(series) - 1): 1169
# range(len(series) - 1): 1170
# range(len(series) - 1): 1171
# range(len(series) - 1): 1172
# range(len(series) - 1): 1173
# range(len(series) - 1): 1174
# range(len(series) - 1): 1175
# range(len(series) - 1): 1176
# range(len(series) - 1): 1177
# range(len(series) - 1): 1178
# range(len(series) - 1): 1179
# range(len(series) - 1): 1180
# range(len(series) - 1): 1181
# range(len(series) - 1): 1182
# range(len(series) - 1): 1183
# range(len(series) - 1): 1184
# range(len(series) - 1): 1185
# range(len(series) - 1): 1186
# range(len(series) - 1): 1187
# range(len(series) - 1): 1188
# range(len(series) - 1): 1189
# range(len(series) - 1): 1190
# range(len(series) - 1): 1191
# range(len(series) - 1): 1192
# range(len(series) - 1): 1193
# range(len(series) - 1): 1194
# range(len(series) - 1): 1195
# range(len(series) - 1): 1196
# range(len(series) - 1): 1197
# range(len(series) - 1): 1198
# range(len(series) - 1): 1199
# range(len(series) - 1): 1200
# range(len(series) - 1): 1201
# range(len(series) - 1): 1202
# range(len(series) - 1): 1203
# range(len(series) - 1): 1204
# range(len(series) - 1): 1205
# range(len(series) - 1): 1206
# range(len(series) - 1): 1207
# range(len(series) - 1): 1208
# range(len(series) - 1): 1209
# range(len(series) - 1): 1210
# range(len(series) - 1): 1211
# range(len(series) - 1): 1212
# range(len(series) - 1): 1213
# range(len(series) - 1): 1214
# range(len(series) - 1): 1215
# range(len(series) - 1): 1216
# range(len(series) - 1): 1217
# range(len(series) - 1): 1218
# range(len(series) - 1): 1219
# range(len(series) - 1): 1220
# range(len(series) - 1): 1221
# range(len(series) - 1): 1222
# range(len(series) - 1): 1223
# range(len(series) - 1): 1224
# range(len(series) - 1): 1225
# range(len(series) - 1): 1226
# range(len(series) - 1): 1227
# range(len(series) - 1): 1228
# range(len(series) - 1): 1229
# range(len(series) - 1): 1230
# range(len(series) - 1): 1231
# range(len(series) - 1): 1232
# range(len(series) - 1): 1233
# range(len(series) - 1): 1234
# range(len(series) - 1): 1235
# range(len(series) - 1): 1236
# range(len(series) - 1): 1237
# range(len(series) - 1): 1238
# range(len(series) - 1): 1239
# range(len(series) - 1): 1240
# range(len(series) - 1): 1241
# range(len(series) - 1): 1242
# range(len(series) - 1): 1243
# range(len(series) - 1): 1244
# range(len(series) - 1): 1245
# range(len(series) - 1): 1246
# range(len(series) - 1): 1247
# range(len(series) - 1): 1248
# range(len(series) - 1): 1249
# range(len(series) - 1): 1250
# range(len(series) - 1): 1251
# range(len(series) - 1): 1252
# range(len(series) - 1): 1253
# range(len(series) - 1): 1254
# range(len(series) - 1): 1255
# range(len(series) - 1): 1256
# range(len(series) - 1): 1257
# range(len(series) - 1): 1258
# range(len(series) - 1): 1259
# range(len(series) - 1): 1260
# range(len(series) - 1): 1261
# range(len(series) - 1): 1262
# range(len(series) - 1): 1263
# range(len(series) - 1): 1264
# range(len(series) - 1): 1265
# range(len(series) - 1): 1266
# range(len(series) - 1): 1267
# range(len(series) - 1): 1268
# range(len(series) - 1): 1269
# range(len(series) - 1): 1270
# range(len(series) - 1): 1271
# range(len(series) - 1): 1272
# range(len(series) - 1): 1273
# range(len(series) - 1): 1274
# range(len(series) - 1): 1275
# range(len(series) - 1): 1276
# range(len(series) - 1): 1277
# range(len(series) - 1): 1278
# range(len(series) - 1): 1279
# range(len(series) - 1): 1280
# range(len(series) - 1): 1281
# range(len(series) - 1): 1282
# range(len(series) - 1): 1283
# range(len(series) - 1): 1284
# range(len(series) - 1): 1285
# range(len(series) - 1): 1286
# range(len(series) - 1): 1287
# range(len(series) - 1): 1288
# range(len(series) - 1): 1289
# range(len(series) - 1): 1290
# range(len(series) - 1): 1291
# range(len(series) - 1): 1292
# range(len(series) - 1): 1293
# range(len(series) - 1): 1294
# range(len(series) - 1): 1295
# range(len(series) - 1): 1296
# range(len(series) - 1): 1297
# range(len(series) - 1): 1298
# range(len(series) - 1): 1299
# range(len(series) - 1): 1300
# range(len(series) - 1): 1301
# range(len(series) - 1): 1302
# range(len(series) - 1): 1303
# range(len(series) - 1): 1304
# range(len(series) - 1): 1305
# range(len(series) - 1): 1306
# range(len(series) - 1): 1307
# range(len(series) - 1): 1308
# range(len(series) - 1): 1309
# range(len(series) - 1): 1310
# range(len(series) - 1): 1311
# range(len(series) - 1): 1312
# range(len(series) - 1): 1313
# range(len(series) - 1): 1314
# range(len(series) - 1): 1315
# range(len(series) - 1): 1316
# range(len(series) - 1): 1317
# range(len(series) - 1): 1318
# range(len(series) - 1): 1319
# range(len(series) - 1): 1320
# range(len(series) - 1): 1321
# range(len(series) - 1): 1322
# range(len(series) - 1): 1323
# range(len(series) - 1): 1324
# range(len(series) - 1): 1325
# range(len(series) - 1): 1326
# range(len(series) - 1): 1327
# range(len(series) - 1): 1328
# range(len(series) - 1): 1329
# range(len(series) - 1): 1330
# range(len(series) - 1): 1331
# range(len(series) - 1): 1332
# range(len(series) - 1): 1333
# range(len(series) - 1): 1334
# range(len(series) - 1): 1335
# range(len(series) - 1): 1336
# range(len(series) - 1): 1337
# range(len(series) - 1): 1338
# range(len(series) - 1): 1339
# range(len(series) - 1): 1340
# range(len(series) - 1): 1341
# range(len(series) - 1): 1342
# range(len(series) - 1): 1343
# range(len(series) - 1): 1344
# range(len(series) - 1): 1345
# range(len(series) - 1): 1346
# range(len(series) - 1): 1347
# range(len(series) - 1): 1348
# range(len(series) - 1): 1349
# range(len(series) - 1): 1350
# range(len(series) - 1): 1351
# range(len(series) - 1): 1352
# range(len(series) - 1): 1353
# range(len(series) - 1): 1354
# range(len(series) - 1): 1355
# range(len(series) - 1): 1356
# range(len(series) - 1): 1357
# range(len(series) - 1): 1358
# range(len(series) - 1): 1359
# range(len(series) - 1): 1360
# range(len(series) - 1): 1361
# range(len(series) - 1): 1362
# range(len(series) - 1): 1363
# range(len(series) - 1): 1364
# range(len(series) - 1): 1365
# range(len(series) - 1): 1366
# range(len(series) - 1): 1367
# range(len(series) - 1): 1368
# range(len(series) - 1): 1369
# range(len(series) - 1): 1370
# range(len(series) - 1): 1371
# range(len(series) - 1): 1372
# range(len(series) - 1): 1373
# range(len(series) - 1): 1374
# range(len(series) - 1): 1375
# range(len(series) - 1): 1376
# range(len(series) - 1): 1377
# range(len(series) - 1): 1378
# range(len(series) - 1): 1379
# range(len(series) - 1): 1380
# range(len(series) - 1): 1381
# range(len(series) - 1): 1382
# range(len(series) - 1): 1383
# range(len(series) - 1): 1384
# range(len(series) - 1): 1385
# range(len(series) - 1): 1386
# range(len(series) - 1): 1387
# range(len(series) - 1): 1388
# range(len(series) - 1): 1389
# range(len(series) - 1): 1390
# range(len(series) - 1): 1391
# range(len(series) - 1): 1392
# range(len(series) - 1): 1393
# range(len(series) - 1): 1394
# range(len(series) - 1): 1395
# range(len(series) - 1): 1396
# range(len(series) - 1): 1397
# range(len(series) - 1): 1398
# range(len(series) - 1): 1399
# range(len(series) - 1): 1400
# range(len(series) - 1): 1401
# range(len(series) - 1): 1402
# range(len(series) - 1): 1403
# range(len(series) - 1): 1404
# range(len(series) - 1): 1405
# range(len(series) - 1): 1406
# range(len(series) - 1): 1407
# range(len(series) - 1): 1408
# range(len(series) - 1): 1409
# range(len(series) - 1): 1410
# range(len(series) - 1): 1411
# range(len(series) - 1): 1412
# range(len(series) - 1): 1413
# range(len(series) - 1): 1414
# range(len(series) - 1): 1415
# range(len(series) - 1): 1416
# range(len(series) - 1): 1417
# range(len(series) - 1): 1418
# range(len(series) - 1): 1419
# range(len(series) - 1): 1420
# range(len(series) - 1): 1421
# range(len(series) - 1): 1422
# range(len(series) - 1): 1423
# range(len(series) - 1): 1424
# range(len(series) - 1): 1425
# range(len(series) - 1): 1426
# range(len(series) - 1): 1427
# range(len(series) - 1): 1428
# range(len(series) - 1): 1429
# range(len(series) - 1): 1430
# range(len(series) - 1): 1431
# range(len(series) - 1): 1432
# range(len(series) - 1): 1433
# range(len(series) - 1): 1434
# range(len(series) - 1): 1435
# range(len(series) - 1): 1436
# range(len(series) - 1): 1437
# range(len(series) - 1): 1438
# range(len(series) - 1): 1439
# range(len(series) - 1): 1440
# range(len(series) - 1): 1441
# range(len(series) - 1): 1442
# range(len(series) - 1): 1443
# range(len(series) - 1): 1444
# range(len(series) - 1): 1445
# range(len(series) - 1): 1446
# range(len(series) - 1): 1447
# range(len(series) - 1): 1448
# range(len(series) - 1): 1449
# range(len(series) - 1): 1450
# range(len(series) - 1): 1451
# range(len(series) - 1): 1452
# range(len(series) - 1): 1453
# range(len(series) - 1): 1454
# range(len(series) - 1): 1455
# range(len(series) - 1): 1456
# range(len(series) - 1): 1457
# range(len(series) - 1): 1458
# range(len(series) - 1): 1459
# range(len(series) - 1): 1460
# range(len(series) - 1): 1461
# range(len(series) - 1): 1462
# range(len(series) - 1): 1463
# range(len(series) - 1): 1464
# range(len(series) - 1): 1465
# range(len(series) - 1): 1466
# range(len(series) - 1): 1467
# range(len(series) - 1): 1468
# range(len(series) - 1): 1469
# range(len(series) - 1): 1470
# range(len(series) - 1): 1471
# range(len(series) - 1): 1472
# range(len(series) - 1): 1473
# range(len(series) - 1): 1474
# range(len(series) - 1): 1475
# range(len(series) - 1): 1476
# range(len(series) - 1): 1477
# range(len(series) - 1): 1478
# range(len(series) - 1): 1479
# range(len(series) - 1): 1480
# range(len(series) - 1): 1481
# range(len(series) - 1): 1482
# range(len(series) - 1): 1483
# range(len(series) - 1): 1484
# range(len(series) - 1): 1485
# range(len(series) - 1): 1486
# range(len(series) - 1): 1487
# range(len(series) - 1): 1488
# range(len(series) - 1): 1489
# range(len(series) - 1): 1490
# range(len(series) - 1): 1491
# range(len(series) - 1): 1492
# range(len(series) - 1): 1493
# range(len(series) - 1): 1494
# range(len(series) - 1): 1495
# range(len(series) - 1): 1496
# range(len(series) - 1): 1497
# range(len(series) - 1): 1498
# range(len(series) - 1): 1499
# range(len(series) - 1): 1500
# range(len(series) - 1): 1501
# range(len(series) - 1): 1502
# range(len(series) - 1): 1503
# range(len(series) - 1): 1504
# range(len(series) - 1): 1505
# range(len(series) - 1): 1506
# range(len(series) - 1): 1507
# range(len(series) - 1): 1508
# range(len(series) - 1): 1509
# range(len(series) - 1): 1510
# range(len(series) - 1): 1511
# range(len(series) - 1): 1512
# range(len(series) - 1): 1513
# range(len(series) - 1): 1514
# range(len(series) - 1): 1515
# range(len(series) - 1): 1516
# range(len(series) - 1): 1517
# range(len(series) - 1): 1518
# range(len(series) - 1): 1519
# range(len(series) - 1): 1520
# range(len(series) - 1): 1521
# range(len(series) - 1): 1522
# range(len(series) - 1): 1523
# range(len(series) - 1): 1524
# range(len(series) - 1): 1525
# range(len(series) - 1): 1526
# range(len(series) - 1): 1527
# range(len(series) - 1): 1528
# range(len(series) - 1): 1529
# range(len(series) - 1): 1530
# range(len(series) - 1): 1531
# range(len(series) - 1): 1532
# range(len(series) - 1): 1533
# range(len(series) - 1): 1534
# range(len(series) - 1): 1535
# range(len(series) - 1): 1536
# range(len(series) - 1): 1537
# range(len(series) - 1): 1538
# range(len(series) - 1): 1539
# range(len(series) - 1): 1540
# range(len(series) - 1): 1541
# range(len(series) - 1): 1542
# range(len(series) - 1): 1543
# range(len(series) - 1): 1544
# range(len(series) - 1): 1545
# range(len(series) - 1): 1546
# range(len(series) - 1): 1547
# range(len(series) - 1): 1548
# range(len(series) - 1): 1549
# range(len(series) - 1): 1550
# range(len(series) - 1): 1551
# range(len(series) - 1): 1552
# range(len(series) - 1): 1553
# range(len(series) - 1): 1554
# range(len(series) - 1): 1555
# range(len(series) - 1): 1556
# range(len(series) - 1): 1557
# range(len(series) - 1): 1558
# range(len(series) - 1): 1559
# range(len(series) - 1): 1560
# range(len(series) - 1): 1561
# range(len(series) - 1): 1562
# range(len(series) - 1): 1563
# range(len(series) - 1): 1564
# range(len(series) - 1): 1565
# range(len(series) - 1): 1566
# range(len(series) - 1): 1567
# range(len(series) - 1): 1568
# range(len(series) - 1): 1569
# range(len(series) - 1): 1570
# range(len(series) - 1): 1571
# range(len(series) - 1): 1572
# range(len(series) - 1): 1573
# range(len(series) - 1): 1574
# range(len(series) - 1): 1575
# range(len(series) - 1): 1576
# range(len(series) - 1): 1577
# range(len(series) - 1): 1578
# range(len(series) - 1): 1579
# range(len(series) - 1): 1580
# range(len(series) - 1): 1581
# range(len(series) - 1): 1582
# range(len(series) - 1): 1583
# range(len(series) - 1): 1584
# range(len(series) - 1): 1585
# range(len(series) - 1): 1586
# range(len(series) - 1): 1587
# range(len(series) - 1): 1588
# range(len(series) - 1): 1589
# range(len(series) - 1): 1590
# range(len(series) - 1): 1591
# range(len(series) - 1): 1592
# range(len(series) - 1): 1593
# range(len(series) - 1): 1594
# range(len(series) - 1): 1595
# range(len(series) - 1): 1596
# range(len(series) - 1): 1597
# range(len(series) - 1): 1598
# range(len(series) - 1): 1599
# range(len(series) - 1): 1600
# range(len(series) - 1): 1601
# range(len(series) - 1): 1602
# range(len(series) - 1): 1603
# range(len(series) - 1): 1604
# range(len(series) - 1): 1605
# range(len(series) - 1): 1606
# range(len(series) - 1): 1607
# range(len(series) - 1): 1608
# range(len(series) - 1): 1609
# range(len(series) - 1): 1610
# range(len(series) - 1): 1611
# range(len(series) - 1): 1612
# range(len(series) - 1): 1613
# range(len(series) - 1): 1614
# range(len(series) - 1): 1615
# range(len(series) - 1): 1616
# range(len(series) - 1): 1617
# range(len(series) - 1): 1618
# range(len(series) - 1): 1619
# range(len(series) - 1): 1620
# range(len(series) - 1): 1621
# range(len(series) - 1): 1622
# range(len(series) - 1): 1623
# range(len(series) - 1): 1624
# range(len(series) - 1): 1625
# range(len(series) - 1): 1626
# range(len(series) - 1): 1627
# range(len(series) - 1): 1628
# range(len(series) - 1): 1629
# range(len(series) - 1): 1630
# range(len(series) - 1): 1631
# range(len(series) - 1): 1632
# range(len(series) - 1): 1633
# range(len(series) - 1): 1634
# range(len(series) - 1): 1635
# range(len(series) - 1): 1636
# range(len(series) - 1): 1637
# range(len(series) - 1): 1638
# range(len(series) - 1): 1639
# range(len(series) - 1): 1640
# range(len(series) - 1): 1641
# range(len(series) - 1): 1642
# range(len(series) - 1): 1643
# range(len(series) - 1): 1644
# range(len(series) - 1): 1645
# range(len(series) - 1): 1646
# range(len(series) - 1): 1647
# range(len(series) - 1): 1648
# range(len(series) - 1): 1649
# range(len(series) - 1): 1650
# range(len(series) - 1): 1651
# range(len(series) - 1): 1652
# range(len(series) - 1): 1653
# range(len(series) - 1): 1654
# range(len(series) - 1): 1655
# range(len(series) - 1): 1656
# range(len(series) - 1): 1657
# range(len(series) - 1): 1658
# range(len(series) - 1): 1659
# range(len(series) - 1): 1660
# range(len(series) - 1): 1661
# range(len(series) - 1): 1662
# range(len(series) - 1): 1663
# range(len(series) - 1): 1664
# range(len(series) - 1): 1665
# range(len(series) - 1): 1666
# range(len(series) - 1): 1667
# range(len(series) - 1): 1668
# range(len(series) - 1): 1669
# ...
# range(len(series) - 1): 24188
# range(len(series) - 1): 24189
# range(len(series) - 1): 24190
# range(len(series) - 1): 24191
# range(len(series) - 1): 24192
# range(len(series) - 1): 24193
# range(len(series) - 1): 24194
# range(len(series) - 1): 24195
# range(len(series) - 1): 24196
# range(len(series) - 1): 24197
# range(len(series) - 1): 24198
# range(len(series) - 1): 24199
# range(len(series) - 1): 24200
# range(len(series) - 1): 24201
# range(len(series) - 1): 24202
# range(len(series) - 1): 24203
# range(len(series) - 1): 24204
# range(len(series) - 1): 24205
# range(len(series) - 1): 24206
# range(len(series) - 1): 24207
# range(len(series) - 1): 24208
# range(len(series) - 1): 24209
# range(len(series) - 1): 24210
# range(len(series) - 1): 24211
# range(len(series) - 1): 24212
# range(len(series) - 1): 24213
# range(len(series) - 1): 24214
# range(len(series) - 1): 24215
# range(len(series) - 1): 24216
# range(len(series) - 1): 24217
# range(len(series) - 1): 24218
# range(len(series) - 1): 24219
# range(len(series) - 1): 24220
# range(len(series) - 1): 24221
# range(len(series) - 1): 24222
# range(len(series) - 1): 24223
# range(len(series) - 1): 24224
# range(len(series) - 1): 24225
# range(len(series) - 1): 24226
# range(len(series) - 1): 24227
# range(len(series) - 1): 24228
# range(len(series) - 1): 24229
# range(len(series) - 1): 24230
# range(len(series) - 1): 24231
# range(len(series) - 1): 24232
# range(len(series) - 1): 24233
# range(len(series) - 1): 24234
# range(len(series) - 1): 24235
# range(len(series) - 1): 24236
# range(len(series) - 1): 24237
# range(len(series) - 1): 24238
# range(len(series) - 1): 24239
# range(len(series) - 1): 24240
# range(len(series) - 1): 24241
# range(len(series) - 1): 24242
# range(len(series) - 1): 24243
# range(len(series) - 1): 24244
# range(len(series) - 1): 24245
# range(len(series) - 1): 24246
# range(len(series) - 1): 24247
# range(len(series) - 1): 24248
# range(len(series) - 1): 24249
# range(len(series) - 1): 24250
# range(len(series) - 1): 24251
# range(len(series) - 1): 24252
# range(len(series) - 1): 24253
# range(len(series) - 1): 24254
# range(len(series) - 1): 24255
# range(len(series) - 1): 24256
# range(len(series) - 1): 24257
# range(len(series) - 1): 24258
# range(len(series) - 1): 24259
# range(len(series) - 1): 24260
# range(len(series) - 1): 24261
# range(len(series) - 1): 24262
# range(len(series) - 1): 24263
# range(len(series) - 1): 24264
# range(len(series) - 1): 24265
# range(len(series) - 1): 24266
# range(len(series) - 1): 24267
# range(len(series) - 1): 24268
# range(len(series) - 1): 24269
# range(len(series) - 1): 24270
# range(len(series) - 1): 24271
# range(len(series) - 1): 24272
# range(len(series) - 1): 24273
# range(len(series) - 1): 24274
# range(len(series) - 1): 24275
# range(len(series) - 1): 24276
# range(len(series) - 1): 24277
# range(len(series) - 1): 24278
# range(len(series) - 1): 24279
# range(len(series) - 1): 24280
# range(len(series) - 1): 24281
# range(len(series) - 1): 24282
# range(len(series) - 1): 24283
# range(len(series) - 1): 24284
# range(len(series) - 1): 24285
# range(len(series) - 1): 24286
# range(len(series) - 1): 24287
# range(len(series) - 1): 24288
# range(len(series) - 1): 24289
# range(len(series) - 1): 24290
# range(len(series) - 1): 24291
# range(len(series) - 1): 24292
# range(len(series) - 1): 24293
# range(len(series) - 1): 24294
# range(len(series) - 1): 24295
# range(len(series) - 1): 24296
# range(len(series) - 1): 24297
# range(len(series) - 1): 24298
# range(len(series) - 1): 24299
# range(len(series) - 1): 24300
# range(len(series) - 1): 24301
# range(len(series) - 1): 24302
# range(len(series) - 1): 24303
# range(len(series) - 1): 24304
# range(len(series) - 1): 24305
# range(len(series) - 1): 24306
# range(len(series) - 1): 24307
# range(len(series) - 1): 24308
# range(len(series) - 1): 24309
# range(len(series) - 1): 24310
# range(len(series) - 1): 24311
# range(len(series) - 1): 24312
# range(len(series) - 1): 24313
# range(len(series) - 1): 24314
# range(len(series) - 1): 24315
# range(len(series) - 1): 24316
# range(len(series) - 1): 24317
# range(len(series) - 1): 24318
# range(len(series) - 1): 24319
# range(len(series) - 1): 24320
# range(len(series) - 1): 24321
# range(len(series) - 1): 24322
# range(len(series) - 1): 24323
# range(len(series) - 1): 24324
# range(len(series) - 1): 24325
# range(len(series) - 1): 24326
# range(len(series) - 1): 24327
# range(len(series) - 1): 24328
# range(len(series) - 1): 24329
# range(len(series) - 1): 24330
# range(len(series) - 1): 24331
# range(len(series) - 1): 24332
# range(len(series) - 1): 24333
# range(len(series) - 1): 24334
# range(len(series) - 1): 24335
# range(len(series) - 1): 24336
# range(len(series) - 1): 24337
# range(len(series) - 1): 24338
# range(len(series) - 1): 24339
# range(len(series) - 1): 24340
# range(len(series) - 1): 24341
# range(len(series) - 1): 24342
# range(len(series) - 1): 24343
# range(len(series) - 1): 24344
# range(len(series) - 1): 24345
# range(len(series) - 1): 24346
# range(len(series) - 1): 24347
# range(len(series) - 1): 24348
# range(len(series) - 1): 24349
# range(len(series) - 1): 24350
# range(len(series) - 1): 24351
# range(len(series) - 1): 24352
# range(len(series) - 1): 24353
# range(len(series) - 1): 24354
# range(len(series) - 1): 24355
# range(len(series) - 1): 24356
# range(len(series) - 1): 24357
# range(len(series) - 1): 24358
# range(len(series) - 1): 24359
# range(len(series) - 1): 24360
# range(len(series) - 1): 24361
# range(len(series) - 1): 24362
# range(len(series) - 1): 24363
# range(len(series) - 1): 24364
# range(len(series) - 1): 24365
# range(len(series) - 1): 24366
# range(len(series) - 1): 24367
# range(len(series) - 1): 24368
# range(len(series) - 1): 24369
# range(len(series) - 1): 24370
# range(len(series) - 1): 24371
# range(len(series) - 1): 24372
# range(len(series) - 1): 24373
# range(len(series) - 1): 24374
# range(len(series) - 1): 24375
# range(len(series) - 1): 24376
# range(len(series) - 1): 24377
# range(len(series) - 1): 24378
# range(len(series) - 1): 24379
# range(len(series) - 1): 24380
# range(len(series) - 1): 24381
# range(len(series) - 1): 24382
# range(len(series) - 1): 24383
# range(len(series) - 1): 24384
# range(len(series) - 1): 24385
# range(len(series) - 1): 24386
# range(len(series) - 1): 24387
# range(len(series) - 1): 24388
# range(len(series) - 1): 24389
# range(len(series) - 1): 24390
# range(len(series) - 1): 24391
# range(len(series) - 1): 24392
# range(len(series) - 1): 24393
# range(len(series) - 1): 24394
# range(len(series) - 1): 24395
# range(len(series) - 1): 24396
# range(len(series) - 1): 24397
# range(len(series) - 1): 24398
# range(len(series) - 1): 24399
# range(len(series) - 1): 24400
# range(len(series) - 1): 24401
# range(len(series) - 1): 24402
# range(len(series) - 1): 24403
# range(len(series) - 1): 24404
# range(len(series) - 1): 24405
# range(len(series) - 1): 24406
# range(len(series) - 1): 24407
# range(len(series) - 1): 24408
# range(len(series) - 1): 24409
# range(len(series) - 1): 24410
# range(len(series) - 1): 24411
# range(len(series) - 1): 24412
# range(len(series) - 1): 24413
# range(len(series) - 1): 24414
# range(len(series) - 1): 24415
# range(len(series) - 1): 24416
# range(len(series) - 1): 24417
# range(len(series) - 1): 24418
# range(len(series) - 1): 24419
# range(len(series) - 1): 24420
# range(len(series) - 1): 24421
# range(len(series) - 1): 24422
# range(len(series) - 1): 24423
# range(len(series) - 1): 24424
# range(len(series) - 1): 24425
# range(len(series) - 1): 24426
# range(len(series) - 1): 24427
# range(len(series) - 1): 24428
# range(len(series) - 1): 24429
# range(len(series) - 1): 24430
# range(len(series) - 1): 24431
# range(len(series) - 1): 24432
# range(len(series) - 1): 24433
# range(len(series) - 1): 24434
# range(len(series) - 1): 24435
# range(len(series) - 1): 24436
# range(len(series) - 1): 24437
# range(len(series) - 1): 24438
# range(len(series) - 1): 24439
# range(len(series) - 1): 24440
# range(len(series) - 1): 24441
# range(len(series) - 1): 24442
# range(len(series) - 1): 24443
# range(len(series) - 1): 24444
# range(len(series) - 1): 24445
# range(len(series) - 1): 24446
# range(len(series) - 1): 24447
# range(len(series) - 1): 24448
# range(len(series) - 1): 24449
# range(len(series) - 1): 24450
# range(len(series) - 1): 24451
# range(len(series) - 1): 24452
# range(len(series) - 1): 24453
# range(len(series) - 1): 24454
# range(len(series) - 1): 24455
# range(len(series) - 1): 24456
# range(len(series) - 1): 24457
# range(len(series) - 1): 24458
# range(len(series) - 1): 24459
# range(len(series) - 1): 24460
# range(len(series) - 1): 24461
# range(len(series) - 1): 24462
# range(len(series) - 1): 24463
# range(len(series) - 1): 24464
# range(len(series) - 1): 24465
# range(len(series) - 1): 24466
# range(len(series) - 1): 24467
# range(len(series) - 1): 24468
# range(len(series) - 1): 24469
# range(len(series) - 1): 24470
# range(len(series) - 1): 24471
# range(len(series) - 1): 24472
# range(len(series) - 1): 24473
# range(len(series) - 1): 24474
# range(len(series) - 1): 24475
# range(len(series) - 1): 24476
# range(len(series) - 1): 24477
# range(len(series) - 1): 24478
# range(len(series) - 1): 24479
# range(len(series) - 1): 24480
# range(len(series) - 1): 24481
# range(len(series) - 1): 24482
# range(len(series) - 1): 24483
# range(len(series) - 1): 24484
# range(len(series) - 1): 24485
# range(len(series) - 1): 24486
# range(len(series) - 1): 24487
# range(len(series) - 1): 24488
# range(len(series) - 1): 24489
# range(len(series) - 1): 24490
# range(len(series) - 1): 24491
# range(len(series) - 1): 24492
# range(len(series) - 1): 24493
# range(len(series) - 1): 24494
# range(len(series) - 1): 24495
# range(len(series) - 1): 24496
# range(len(series) - 1): 24497
# range(len(series) - 1): 24498
# range(len(series) - 1): 24499
# range(len(series) - 1): 24500
# range(len(series) - 1): 24501
# range(len(series) - 1): 24502
# range(len(series) - 1): 24503
# range(len(series) - 1): 24504
# range(len(series) - 1): 24505
# range(len(series) - 1): 24506
# range(len(series) - 1): 24507
# range(len(series) - 1): 24508
# range(len(series) - 1): 24509
# range(len(series) - 1): 24510
# range(len(series) - 1): 24511
# range(len(series) - 1): 24512
# range(len(series) - 1): 24513
# range(len(series) - 1): 24514
# range(len(series) - 1): 24515
# range(len(series) - 1): 24516
# range(len(series) - 1): 24517
# range(len(series) - 1): 24518
# range(len(series) - 1): 24519
# range(len(series) - 1): 24520
# range(len(series) - 1): 24521
# range(len(series) - 1): 24522
# range(len(series) - 1): 24523
# range(len(series) - 1): 24524
# range(len(series) - 1): 24525
# range(len(series) - 1): 24526
# range(len(series) - 1): 24527
# range(len(series) - 1): 24528
# range(len(series) - 1): 24529
# range(len(series) - 1): 24530
# range(len(series) - 1): 24531
# range(len(series) - 1): 24532
# range(len(series) - 1): 24533
# range(len(series) - 1): 24534
# range(len(series) - 1): 24535
# range(len(series) - 1): 24536
# range(len(series) - 1): 24537
# range(len(series) - 1): 24538
# range(len(series) - 1): 24539
# range(len(series) - 1): 24540
# range(len(series) - 1): 24541
# range(len(series) - 1): 24542
# range(len(series) - 1): 24543
# range(len(series) - 1): 24544
# range(len(series) - 1): 24545
# range(len(series) - 1): 24546
# range(len(series) - 1): 24547
# range(len(series) - 1): 24548
# range(len(series) - 1): 24549
# range(len(series) - 1): 24550
# range(len(series) - 1): 24551
# range(len(series) - 1): 24552
# range(len(series) - 1): 24553
# range(len(series) - 1): 24554
# range(len(series) - 1): 24555
# range(len(series) - 1): 24556
# range(len(series) - 1): 24557
# range(len(series) - 1): 24558
# range(len(series) - 1): 24559
# range(len(series) - 1): 24560
# range(len(series) - 1): 24561
# range(len(series) - 1): 24562
# range(len(series) - 1): 24563
# range(len(series) - 1): 24564
# range(len(series) - 1): 24565
# range(len(series) - 1): 24566
# range(len(series) - 1): 24567
# range(len(series) - 1): 24568
# range(len(series) - 1): 24569
# range(len(series) - 1): 24570
# range(len(series) - 1): 24571
# range(len(series) - 1): 24572
# range(len(series) - 1): 24573
# range(len(series) - 1): 24574
# range(len(series) - 1): 24575
# range(len(series) - 1): 24576
# range(len(series) - 1): 24577
# range(len(series) - 1): 24578
# range(len(series) - 1): 24579
# range(len(series) - 1): 24580
# range(len(series) - 1): 24581
# range(len(series) - 1): 24582
# range(len(series) - 1): 24583
# range(len(series) - 1): 24584
# range(len(series) - 1): 24585
# range(len(series) - 1): 24586
# range(len(series) - 1): 24587
# range(len(series) - 1): 24588
# range(len(series) - 1): 24589
# range(len(series) - 1): 24590
# range(len(series) - 1): 24591
# range(len(series) - 1): 24592
# range(len(series) - 1): 24593
# range(len(series) - 1): 24594
# range(len(series) - 1): 24595
# range(len(series) - 1): 24596
# range(len(series) - 1): 24597
# range(len(series) - 1): 24598
# range(len(series) - 1): 24599
# range(len(series) - 1): 24600
# range(len(series) - 1): 24601
# range(len(series) - 1): 24602
# range(len(series) - 1): 24603
# range(len(series) - 1): 24604
# range(len(series) - 1): 24605
# range(len(series) - 1): 24606
# range(len(series) - 1): 24607
# range(len(series) - 1): 24608
# range(len(series) - 1): 24609
# range(len(series) - 1): 24610
# range(len(series) - 1): 24611
# range(len(series) - 1): 24612
# range(len(series) - 1): 24613
# range(len(series) - 1): 24614
# range(len(series) - 1): 24615
# range(len(series) - 1): 24616
# range(len(series) - 1): 24617
# range(len(series) - 1): 24618
# range(len(series) - 1): 24619
# range(len(series) - 1): 24620
# range(len(series) - 1): 24621
# range(len(series) - 1): 24622
# range(len(series) - 1): 24623
# range(len(series) - 1): 24624
# range(len(series) - 1): 24625
# range(len(series) - 1): 24626
# range(len(series) - 1): 24627
# range(len(series) - 1): 24628
# range(len(series) - 1): 24629
# range(len(series) - 1): 24630
# range(len(series) - 1): 24631
# range(len(series) - 1): 24632
# range(len(series) - 1): 24633
# range(len(series) - 1): 24634
# range(len(series) - 1): 24635
# range(len(series) - 1): 24636
# range(len(series) - 1): 24637
# range(len(series) - 1): 24638
# range(len(series) - 1): 24639
# range(len(series) - 1): 24640
# range(len(series) - 1): 24641
# range(len(series) - 1): 24642
# range(len(series) - 1): 24643
# range(len(series) - 1): 24644
# range(len(series) - 1): 24645
# range(len(series) - 1): 24646
# range(len(series) - 1): 24647
# range(len(series) - 1): 24648
# range(len(series) - 1): 24649
# range(len(series) - 1): 24650
# range(len(series) - 1): 24651
# range(len(series) - 1): 24652
# range(len(series) - 1): 24653
# range(len(series) - 1): 24654
# range(len(series) - 1): 24655
# range(len(series) - 1): 24656
# range(len(series) - 1): 24657
# range(len(series) - 1): 24658
# range(len(series) - 1): 24659
# range(len(series) - 1): 24660
# range(len(series) - 1): 24661
# range(len(series) - 1): 24662
# range(len(series) - 1): 24663
# range(len(series) - 1): 24664
# range(len(series) - 1): 24665
# range(len(series) - 1): 24666
# range(len(series) - 1): 24667
# range(len(series) - 1): 24668
# range(len(series) - 1): 24669
# range(len(series) - 1): 24670
# range(len(series) - 1): 24671
# range(len(series) - 1): 24672
# range(len(series) - 1): 24673
# range(len(series) - 1): 24674
# range(len(series) - 1): 24675
# range(len(series) - 1): 24676
# range(len(series) - 1): 24677
# range(len(series) - 1): 24678
# range(len(series) - 1): 24679
# range(len(series) - 1): 24680
# range(len(series) - 1): 24681
# range(len(series) - 1): 24682
# range(len(series) - 1): 24683
# range(len(series) - 1): 24684
# range(len(series) - 1): 24685
# range(len(series) - 1): 24686
# range(len(series) - 1): 24687
# range(len(series) - 1): 24688
# range(len(series) - 1): 24689
# range(len(series) - 1): 24690
# range(len(series) - 1): 24691
# range(len(series) - 1): 24692
# range(len(series) - 1): 24693
# range(len(series) - 1): 24694
# range(len(series) - 1): 24695
# range(len(series) - 1): 24696
# range(len(series) - 1): 24697
# range(len(series) - 1): 24698
# range(len(series) - 1): 24699
# range(len(series) - 1): 24700
# range(len(series) - 1): 24701
# range(len(series) - 1): 24702
# range(len(series) - 1): 24703
# range(len(series) - 1): 24704
# range(len(series) - 1): 24705
# range(len(series) - 1): 24706
# range(len(series) - 1): 24707
# range(len(series) - 1): 24708
# range(len(series) - 1): 24709
# range(len(series) - 1): 24710
# range(len(series) - 1): 24711
# range(len(series) - 1): 24712
# range(len(series) - 1): 24713
# range(len(series) - 1): 24714
# range(len(series) - 1): 24715
# range(len(series) - 1): 24716
# range(len(series) - 1): 24717
# range(len(series) - 1): 24718
# range(len(series) - 1): 24719
# range(len(series) - 1): 24720

# %%
# 訓練データとテストデータに分割
# Xsとysは、入力データと対応するラベル。訓練に使用される
# test_size=.25は、全体のデータセットのうち25%をテストデータとして使用することを指定する
# random_state=42は、データを分割する際のランダムシードを指定する
# shuffle=Falseは、データをシャッフルしないことを指定。時系列データの場合、データの順序が重要であるため、通常はシャッフルしない。
# 出力は、訓練データ（X_trainとy_train）とテストデータ（X_testとy_test）の4つのデータセットです。これらは、モデルの訓練と評価に使用される
X_train, X_test, y_train, y_test = train_test_split(
    Xs,
    ys,
    test_size=.25,
    random_state=42,
    shuffle=False)

# 訓練データ（X_trainとy_train）をデータセットに変換
ds = torch.utils.data.TensorDataset(X_train, y_train)
# 訓練データをバッチ処理するためのデータローダーを作成
# バッチサイズは一度にネットワークに供給されるデータの数（バッチサイズ）を指定
dataloader_train = torch.utils.data.DataLoader(ds, batch_size=8, shuffle=True)
print(f"Train size: {len(X_train)} Test size: {len(X_test)}")

net = NN()
# 損失関数を定義する。平均二乗誤差（MSE）を使用する
# 損失関数は、モデルの予測が実際のラベルからどれだけ離れているかを測定する
# 訓練中には、この損失を最小化するようにモデルのパラメータが調整される
criterion = nn.MSELoss()
# 最適化アルゴリズムを定義する。Adamアルゴリズムを使用する
# Adamは、確率的勾配降下法（SGD）の一種であり、モデルのパラメータを最適化するために使用される
# lr=0.001は、学習率を指定する。学習率は、モデルのパラメータを更新するステップの大きさを制御する
optimizer = optim.Adam(net.parameters(), lr=0.001)

# %%
iteration = 0
# エポックのループです。エポックとは、訓練データ全体を一度通過することを指す
for epoch in range(10):
    # バッチのループ。バッチとは、訓練データを一部分ずつ処理するための小さなデータの塊
    for i, (datapoints, labels) in enumerate(dataloader_train):
        # 最適化アルゴリズムの勾配をゼロにリセット
        optimizer.zero_grad()

        # モデルの損失（エラー）を計算します。この損失は、モデルの予測と実際のラベルとの差を表す
        # sample_elboは、ベイジアンニューラルネットワークの損失を計算するための関数
        loss = net.sample_elbo(
            inputs=datapoints,
            labels=labels,
            criterion=criterion,
            sample_nbr=3,
            complexity_cost_weight=1 / X_train.shape[0])
        # 損失に対する各パラメータの勾配を計算する。パラメータを更新するために必要
        loss.backward()
        # 計算された勾配を使用して、モデルのパラメータを更新する
        optimizer.step()

        # 250回のイテレーションごとに、テストデータに対する損失を計算し、表示する
        iteration += 1
        if iteration % 250 == 0:
            preds_test = net(X_test)[:, 0].unsqueeze(1)
            loss_test = criterion(preds_test, y_test)
            print("Iteration: {} Val-loss: {:.4f}".format(str(iteration), loss_test))

# %%
#pred_unscaled
original = df["Close"][1:][window_size:]  # データフレームdfから「Close」列を取得し、最初の要素とwindow_size以降の要素をスキップ
df_pred = pd.DataFrame(original)
df_pred["Date"] = df.Date
df["Date"] = pd.to_datetime(df_pred["Date"])  # 「Date」列を日付型（datetime）に変換
df_pred = df_pred.reset_index()  # インデックスを0から始まる連番になるようにリセット

# %%
def pred_stock_future(X_test, future_length, sample_nbr=10):
    """
    与えられたテストデータ X_test を用いて、未来の株価を予測するためのものです。
    ベイジアンニューラルネットワークのモデルを使用して、指定された未来の日数 future_length にわたる株価の予測値を生成します。
    """
    global window_size
    global X_train
    global Xs
    global scaler

    # 予測値を格納するための空のリストを作成
    preds_test = []
    # 予測を開始する最初のデータポイントを取得
    # テストデータの最初のウィンドウを取得し、それをdeque（両端キュー）に変換します。
    # dequeは、両端で要素の追加や削除が高速に行えるリスト型のデータ構造です。
    test_begin = X_test[0:1, :, :]
    test_deque = deque(test_begin[0, :, 0].tolist(), maxlen=window_size)
    # 予測値のインデックスをdf["Date"] のような日付型を生成
    idx_pred = df["Date"][len(X_train) + window_size:].values
    # idx_pred = np.arange(len(X_train), len(Xs))

    # テストデータの各ウィンドウに対してループ
    for i in range(len(X_test)):
        # テストデータのウィンドウをモデルに供給し、未来の株価を予測
        # 現在のウィンドウをニューラルネットワークの入力として使用できる形式に変換します。
        as_net_input = torch.tensor(test_deque).unsqueeze(0).unsqueeze(2)
        # 現在のウィンドウに対する予測値を生成します。sample_nbr 回繰り返され、それぞれの予測値がリスト pred に格納されます。
        pred = [net(as_net_input).cpu().item() for i in range(sample_nbr)]
        # 生成した予測値の平均をdequeに追加し、予測値のリスト全体を preds_test に追加します。
        test_deque.append(torch.tensor(pred).mean().cpu().item())
        preds_test.append(pred)

        # 指定された未来の日数ごとに、dequeとテストデータのウィンドウを更新します。
        if i % future_length == 0:
            #our inptus become the i index of our X_test
            #That tweak just helps us with shape issues
            test_begin = X_test[i:i + 1, :, :]
            test_deque = deque(test_begin[0, :, 0].tolist(), maxlen=window_size)

    #preds_test = np.array(preds_test).reshape(-1, 1)
    #preds_test_unscaled = scaler.inverse_transform(preds_test)

    return idx_pred, preds_test

# %%
def get_confidence_intervals(preds_test, ci_multiplier):
    """
    予測結果の信頼区間を計算するためのものです。具体的には、予測値の平均と標準偏差を用いて、信頼区間の上限と下限を計算します。
    """
    global scaler
    # 予測値をPyTorchのテンソルに変換
    preds_test = torch.tensor(preds_test)
    # 予測値の平均を計算
    pred_mean = preds_test.mean(1)
    # 予測値の標準偏差を計算。テンソルからnumpy配列に変換。
    pred_std = preds_test.std(1).detach().cpu().numpy()
    # 予測値の標準偏差をPyTorchのテンソルに変換
    pred_std = torch.tensor((pred_std))
    #print(pred_std)

    # 信頼区間の上限と下限を計算します。ci_multiplierは信頼区間の幅を制御するパラメータ
    upper_bound = pred_mean + (pred_std * ci_multiplier)
    lower_bound = pred_mean - (pred_std * ci_multiplier)

    # 平均値、上限、下限を元のスケールに戻します。これは、モデルの入力データがスケーリング（正規化）されていた場合に必要です。
    pred_mean_final = pred_mean.unsqueeze(1).detach().cpu().numpy()
    pred_mean_unscaled = scaler.inverse_transform(pred_mean_final)

    upper_bound_unscaled = upper_bound.unsqueeze(1).detach().cpu().numpy()
    upper_bound_unscaled = scaler.inverse_transform(upper_bound_unscaled)

    lower_bound_unscaled = lower_bound.unsqueeze(1).detach().cpu().numpy()
    lower_bound_unscaled = scaler.inverse_transform(lower_bound_unscaled)

    return pred_mean_unscaled, upper_bound_unscaled, lower_bound_unscaled

# %%
# future_length=7
future_length = 3
# sample_nbr = 4
sample_nbr = 10
# ci_multiplier = 5
ci_multiplier = 2
idx_pred, preds_test = pred_stock_future(X_test, future_length, sample_nbr)
pred_mean_unscaled, upper_bound_unscaled, lower_bound_unscaled = get_confidence_intervals(preds_test,
                                                                                          ci_multiplier)

# %%
print(idx_pred)

# %%
# 実際の株価（df.Close）の最後の部分（予測結果と同じ長さ）を取得し、それを2次元配列に変換しています。
# y = np.array(df.close[-750:]).reshape(-1, 1)
y = np.array(df.Close[-len(upper_bound_unscaled):]).reshape(-1, 1)
# 予測結果の信頼区間の上限upper_bound_unscaled と下限 lower_bound_unscaled を比較し、それらが実際のデータ y の範囲内にあるかどうかを確認します。
under_upper = upper_bound_unscaled > y
over_lower = lower_bound_unscaled < y
# 上記の2つのブール値配列が等しいかどうかを判定しています。これは、実際の株価が信頼区間内に収まっている場合にTrueとなります。
total = (under_upper == over_lower)

print("{} our predictions are in our confidence interval".format(np.mean(total)))

# %%
# プロットの色設定を定義します
params = {"ytick.color": "black",
          "xtick.color": "black",
          "axes.labelcolor": "black",
          "axes.edgecolor": "black"}
plt.rcParams.update(params)
# 実際の株価をプロットします。x軸は日付（df_pred.index）、y軸は株価（df_pred.Close）です。
# 線の色は黒で、ラベルは"Real"としています。
plt.plot(df_pred.index,
         df_pred.Close,
         color='black',
         label="Real")
# 予測した株価をプロットします。x軸は予測値のインデックス（idx_pred）、y軸は予測値（pred_mean_unscaled）です。
# 線の色は赤で、ラベルは"Prediction for {} days, than consult"としています。
plt.plot(idx_pred,
         pred_mean_unscaled,
         label="Prediction for {} days, than consult".format(future_length),
         color="red")
# 予測結果の信頼区間をプロットします。
# x軸は予測値のインデックス（idx_pred）、
# y軸は信頼区間の上限（upper_bound_unscaled）と下限（lower_bound_unscaled）です。
# 領域の色は緑で、ラベルは"Confidence interval"としています。
# alpha=0.5により領域の色を半透明にしています。
plt.fill_between(x=idx_pred,
                 y1=upper_bound_unscaled[:, 0],
                 y2=lower_bound_unscaled[:, 0],
                 facecolor='green',
                 label="Confidence interval",
                 alpha=0.5)
# プロットの凡例を表示します。 
plt.legend()

# %%
params = {"ytick.color": "black",
          "xtick.color": "black",
          "axes.labelcolor": "black",
          "axes.edgecolor": "black"}
plt.rcParams.update(params)

plt.fill_between(x=idx_pred,
                 y1=upper_bound_unscaled[:, 0],
                 y2=lower_bound_unscaled[:, 0],
                 facecolor='green',
                 label="Confidence interval",
                 alpha=0.75)

plt.plot(idx_pred,
         df_pred.Close[-len(pred_mean_unscaled):],
         label="Real",
         alpha=1,
         color='black',
         linewidth=0.5)

plt.plot(idx_pred,
         pred_mean_unscaled,
         label="Prediction for {} days, than consult".format(future_length),
         color="red",
         alpha=0.5)

plt.legend()

# %%
# Date、original, pred_mean_unscaled, upper_bound_unscaled, lower_bound_unscaledの値をCSVに出力する
# 保存先はdata/prediction.csvとする
# ヘッダーはDate、original、pred_mean_unscaled、upper_bound_unscaled、lower_bound_unscaledとする
# df_pred.columns = ["Date", "original", "pred_mean_unscaled", "upper_bound_unscaled", "lower_bound_unscaled"]
# df_pred["Date"] = df.Date
# df_pred["original"] = original
df_new = pd.DataFrame()
df_new.index = idx_pred
df_new["real"] = df_pred.Close[-len(pred_mean_unscaled):]
df_new["pred_mean_unscaled"] = pred_mean_unscaled
df_new["upper_bound_unscaled"] = upper_bound_unscaled[:, 0]
df_new["lower_bound_unscaled"] = lower_bound_unscaled[:, 0]

# 現時刻を取得して、YYYY_MM_DD-HH_mm_SSのフォーマットにする
import datetime

# CSVファイルに出力
df_new.to_csv(f"data/prediction_{input_file.split('.')[0]}_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}.csv")

# %%
import os

for i in range(3):
    os.system('afplay /System/Library/Sounds/Glass.aiff')
